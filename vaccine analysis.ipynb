# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import csv
import folium
import operator
import itertools
# Handle date time conversions between pandas and matplotlib
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
sns.set_theme(style="darkgrid")
#Using modules needed to represent the data and visualize it efficiently, namely seaborn.
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-11-45858b9b61b3> in <module>
# ----> 1 import matplotlib.pyplot as plt
#       2 import seaborn as sns
#       3 import pandas as pd
#       4 import numpy as np
#       5 import csv
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
#Setup dataframe
df = pd.read_csv("vaccinedist.csv",error_bad_lines=False,quoting=csv.QUOTE_NONE,encoding='utf-8')
ny = df[df['Jurisdiction'] == 'New York']
ny
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-316b2e4ebff7> in <module>
#       1 #Setup dataframe
# ----> 2 df = pd.read_csv("vaccinedist.csv",error_bad_lines=False,quoting=csv.QUOTE_NONE,encoding='utf-8')
#       3 ny = df[df['Jurisdiction'] == 'New York']
#       4 ny
#
# NameError: name 'pd' is not defined

# %%
vacOneSum = 0
for values in ny.alloc_one:
    vacOneSum+=values
values
# Out:
# 96525

# %%
ny['Date'] = pd.to_datetime(ny.Date)
ny.sort_values(by='Date')
ny
# Out:
# <ipython-input-37-bd0e1246370b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ny['Date'] = pd.to_datetime(ny.Date)
#      Jurisdiction       Date  alloc_one  alloc_two
# 7        New York 2021-04-19     168480     168480
# 70       New York 2021-04-12     156780     156780
# 133      New York 2021-04-05     153270     153270
# 196      New York 2021-03-29     188370     188370
# 259      New York 2021-03-22     153270     153270
# 322      New York 2021-03-15     150930     150930
# 385      New York 2021-03-08     140400     140400
# 480      New York 2021-03-01     128700     128700
# 543      New York 2021-02-22     112320     112320
# 606      New York 2021-02-15      71175      71175
# ...

# %%
datesonly = ny['Date']
timespan = datesonly['2020-12-14':'2021-04-19']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-eccab8600316> in <module>
#       1 datesonly = ny['Date']
# ----> 2 timespan = datesonly['2020-12-14':'2021-04-19']
#
# c:\users\alap6\appdata\local\programs\python\python38\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     875             return self._get_values(key)
#     876
# --> 877         return self._get_with(key)
#     878
#     879     def _get_with(self, key):
#
# c:\users\alap6\appdata\local\programs\python\python38\lib\site-packages\pandas\core\series.py in _get_with(self, key)
#     882             # _convert_slice_indexer to determine if this slice is positional
#     883             #  or label based, and if the latter, convert to positional
# --> 884             slobj = self.index._convert_slice_indexer(key, kind="getitem")
#     885             return self._slice(slobj)
# ...
